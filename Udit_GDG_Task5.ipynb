# %% [markdown]
# <a href="https://colab.research.google.com/github/uditsevak/Udit_GDG_Tasks/blob/Task-5/Udit_GDG_Task5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **GDG TASK 5**
# ![GDG On Campus - Centered - 10x10 White.png](data:image/png;base64,...)

# %% [markdown]
# ## For this task we will be starting with Deep Learning.
# ### Deep learning is a method in artificial intelligence (AI) that teaches computers to process data in a way that is inspired by the human brain.
# ### You can read more about it on :
# https://aws.amazon.com/what-is/deep-learning/
#
# https://www.ibm.com/topics/deep-learning

# %% [markdown]
# ### The first thing in Deep Learning is the existence of Artificial Neural Networks.
# ### What is Artificial Neural Network?
#
# Artificial Neural Network ANN is an efficient computing system whose central theme is borrowed from the analogy of biological neural networks. ANNs are also named as “artificial neural systems,” or “parallel distributed processing systems,” or “connectionist systems.” ANN acquires a large collection of units that are interconnected in some pattern to allow communication between the units. These units, also referred to as nodes or neurons, are simple processors which operate in parallel.
#
# Every neuron is connected with other neuron through a connection link. Each connection link is associated with a weight that has information about the input signal. This is the most useful information for neurons to solve a particular problem because the weight usually excites or inhibits the signal that is being communicated. Each neuron has an internal state, which is called an activation signal. Output signals, which are produced after combining the input signals and activation rule, may be sent to other units.
#
# You can learn about their working using this playlist:
#
# https://www.youtube.com/playlist?list=PLZHQObOWTQDNU6R1_67000Dx_ZCJB-3pi
#
# https://www.youtube.com/watch?v=hfK_dvC-avg&list=PLZbbT5o_s2xq7LwI2y8_QtvuXZedL6tQU&index=3

# %% [markdown]
# ### Components of ANN:
# **The Input Layer** — Represents the input variables plus the bias term. Hence if there are n input variables, the size of the input layer is n + 1, where + 1 is the bias term
#
# **The Hidden Layer/ Layers** — These signify neurons where all mathematical calculations are done. Note a given neural network can have more than one neuron in a hidden layer or multiple hidden layers as well
#
# **The Activation Function** — Converts the output of a given layer before passing on the information to consecutive layers. Activation functions are mathematical equations that determine the output of a given neural network. The is a part of each neuron in the hidden layers and determines output relevant for prediction
#
# **The Output Layer** — The final “output prediction” of the network
#
# **Forward Propagation** — Calculating the output of each iteration from the input layer to the output layer
#
# **Backward Propagation** — Calculates revised weights (w1, w2, w3, and b1) after each forward propagation by analyzing the derivative of the cost function used to optimize the model output
#
# **Learning Rate** — Determined the percentage change attributed to each weight and bias term after every backward propagation, i.e. controls the speed at which the model learns information about the data

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# For more Information on Layers of Neural Networks: https://www.youtube.com/watch?v=FK77zZxaBoI&list=PLZbbT5o_s2xq7LwI2y8_QtvuXZedL6tQU&index=4

# %% [markdown]
# ## Ok, so now that we are done with the basic Theoretical Concept of ANN. Let's implement a single neuron NN.
#
# ### The steps involved for this are:
# 1. Create a Node
# 2. Initialize the node with weights and bias.
# 3. Pass an Input Data to it.
# 4. Apply a learning rule on it.
# 5. Modify its weights and bias based on the Learning Rule.
# 6. Repeat steps 3 to 4 for a different input data for some number of epochs.

# %% [markdown]
# From the YouTube Videos, you must be clear with the concept of Nodes, Weights and Biases. So, let's learn about Learning Rules.
# Neural networks are made functional with the help of training that follows some kind of a learning rule. A learning rule in ANN is nothing but a set of instructions or a mathematical formula that helps in reinforcing a pattern, thus improving the efficiency of a neural network. There are 6 such learning rules that are widely used by neural networks for training.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can read about them individually at:
#
# https://www.tutorialspoint.com/types-of-learning-rules-in-ann
#
# https://www.geeksforgeeks.org/types-of-learning-rules-in-ann/

# %% [markdown]
# ![WhatsApp Image 2023-10-18 at 09.19.41_935144a5.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np # Required as all nodes are nothing but matrices

# %%
# Lets Recreate a NN that acts as a OR Gate
# Perceptron Learning Rule
class PerceptronNetwork:
    def __init__(self, input_size):
        self.weights = np.random.rand(input_size)  # Initialize the weights according to the table above (Hint: Perceptron requires 'n' random weights)
        self.bias = np.random.rand(1)

    def predict(self, x):
        # Here, we are using a Step Function as our activation function (WHY? TUM BATAO SOCHKE... ANSWER ALREADY BATA CHUKA HU)
        weighted_sum = np.dot(x,self.weights) + self.bias  # ______ (Hint: Matrix Multiply Input and Old Weights and offset with the bias)
        return 1 if weighted_sum >= 0 else 0

    def train(self, X, y, learning_rate, epochs):
        for _ in range(epochs): # for each epoch
            for i in range(len(X)): # for each input
                prediction = self.predict(X[i]) # Get Prediction on X[i]
                error = y[i]-prediction # Calcualte the difference between actual and predicted to get error
                self.weights += learning_rate * error * X[i]# Use Perceptron Formula from the table above
                self.bias += learning_rate * error # Modify the Bias by multiplying learning rate and error

# %%
# Create the object and inputs
perceptron_network = PerceptronNetwork(input_size=2) # OR me kitne inputs hote?
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]]) # Truth Table of OR Gate
y = np.array([0, 1, 1, 1])

# %%
# Start Training the Network
perceptron_network.train(X,y,learning_rate=0.1,epochs=10)

# %%
# Now that the network is trained, use it for prediction
for x in X:
    prediction = perceptron_network.predict(x)
    print(f"Input: {x}, Perceptron Prediction: {prediction}")
# Out:
# Input: [0 0], Perceptron Prediction: 0
# Input: [0 1], Perceptron Prediction: 1
# Input: [1 0], Perceptron Prediction: 1
# Input: [1 1], Perceptron Prediction: 1

# %% [markdown]
# As you can see, a single epoch does not give all correct solutions.. Lets increase the epochs

# %%
# Write Code here

# %% [markdown]
# As you can see, the network learned and improved. You can view the weights of the node as well

# %%
perceptron_network.weights
# Out:
# array([0.82675866, 0.40755761])

# %% [markdown]
# You can utilise this link to understand how you can accept Input as a Pandas Dataframe and recreate the Perceptron Rule
#
# https://learnai1.home.blog/2019/11/16/perceptron-delta-rule-python-implementation/

# %% [markdown]
# We have now implemented a binary classifier using a Single Neuron Neural Network. There are a variety of Neural Networks like Feedforward NN, Backpropagted NN etc. based on how they operate their errors and weight updations. You can read this article about them and implement it if you feel so (**BONUS**):
#
# https://www.baeldung.com/cs/neural-networks-backprop-vs-feedforward
#
# Scratch Implementation of such a network is available in the resource below. This is a **DIFFICULT** Task to do so kindly follow it up later on.
#
# https://medium.com/@simple.schwarz/how-to-implement-a-feedforward-backpropagation-neural-network-in-python-with-mnist-dataset-a2e5888b3015

# %% [markdown]
# ## Let us implement a ANN using Keras and consider a actual problem. (No resources for this.. Keras ka documentation padho) https://keras.io/api/models/sequential/
# ## https://keras.io/api/layers/
#
# **USE** same data set (titanic) which you had preprocessed in the earlier task to create a neural network which predicts the survival rate.

# %%
#import all the prerequisites like tensorflow and keras
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense,Activation
from sklearn.model_selection import train_test_split
import re
from keras.optimizers import SGD,Adam
import numpy as np
from numpy.random import seed
import tensorflow as tf
import random as rn
seed(100)
rn.seed(100)
tf.random.set_seed(100)

# %% [markdown]
# A dense layer does exactly what you did in the perceptron network's weighted sum variable.

# %%
# create a model using sequential
# add 3 dense layers, with input shape (28,) only for the first layer.
# Add whatever activation function you like.
model=Sequential([
    Dense(28,activation="relu",input_shape=(26,)),
    Dense(16,activation="relu"),
    Dense(1,activation="sigmoid")] # For the final layer, keep the activation as sigmoid
)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
#import your dataset and write out the code for normalising and preprocessing the data. By now you should be familiar with this step. Remember, for the best accuracy and
#performance of the model, it is best if we provide the model with "clean" data
df_train = pd.read_csv("train.csv")
df_train['Title'] = df_train['Name'].apply(lambda x: re.search('([A-Za-z]+)\.', x).group(1))
df_train.drop(['PassengerId','Ticket','Name'],axis=1,inplace=True)

# %%
percent_missing = df_train.isnull().sum() * 100 / len(df_train)

missing_value_df_train = pd.DataFrame({'column_name': df_train.columns,
                                 'percent_missing': percent_missing})

columns_to_remove = missing_value_df_train[missing_value_df_train['percent_missing'] > 50]['column_name']
df_train = df_train.drop(columns=columns_to_remove)
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked Title
# 0         0       3    male  22.0      1      0   7.2500        S    Mr
# 1         1       1  female  38.0      1      0  71.2833        C   Mrs
# 2         1       3  female  26.0      0      0   7.9250        S  Miss
# 3         1       1  female  35.0      1      0  53.1000        S   Mrs
# 4         0       3    male  35.0      0      0   8.0500        S    Mr

# %%
df_train['Embarked'].fillna(df_train['Embarked'].mode()[0], inplace=True)
df_train['Age'].fillna(df_train['Age'].mean(), inplace=True)
# Out:
# <ipython-input-20-7b51bac42d10>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Embarked'].fillna(df_train['Embarked'].mode()[0], inplace=True)
# <ipython-input-20-7b51bac42d10>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_train['Age'].fillna(df_train['Age'].mean(), inplace=True)

# %%
df_train['Family_members'] = df_train['SibSp'] + df_train['Parch']

# %%
cols_to_norm = ['Age', 'Fare', 'Family_members']
df_train[cols_to_norm] = df_train[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
cols_to_encode = ['Pclass', 'Sex', 'Title', 'Embarked']
df_train = pd.get_dummies(df_train, columns=cols_to_encode, drop_first=True)

# %%
y = df_train['Survived']
X = df_train.drop('Survived', axis=1)

# %%
#Split the dataset into train,test dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#compile your model using optimizers like "SGD","ADAM". Hint: model.compile()
#use model.fit to train
model.compile(optimizer = 'adam',
               loss = 'categorical_crossentropy',
               metrics = ['accuracy']
               )

# %%
model.fit(X_train,y_train,epochs=10,validation_data=(X_test,y_test))
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/keras/src/losses/losses.py:27: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6285 - loss: 0.0000e+00
# /usr/local/lib/python3.10/dist-packages/keras/src/losses/losses.py:27: SyntaxWarning: In loss categorical_crossentropy, expected y_pred.shape to be (batch_size, num_classes) with num_classes > 1. Received: y_pred.shape=(None, 1). Consider using 'binary_crossentropy' if you only have 2 classes.
#   return self.fn(y_true, y_pred, **self._fn_kwargs)
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 3s 67ms/step - accuracy: 0.6287 - loss: 0.0000e+00 - val_accuracy: 0.5933 - val_loss: 0.0000e+00
# Epoch 2/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6227 - loss: 0.0000e+00 - val_accuracy: 0.5858 - val_loss: 0.0000e+00
# Epoch 3/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6065 - loss: 0.0000e+00 - val_accuracy: 0.5858 - val_loss: 0.0000e+00
# Epoch 4/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6065 - loss: 0.0000e+00 - val_accuracy: 0.5858 - val_loss: 0.0000e+00
# Epoch 5/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6065 - loss: 0.0000e+00 - val_accuracy: 0.5858 - val_loss: 0.0000e+00
# Epoch 6/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6065 - loss: 0.0000e+00 - val_accuracy: 0.5858 - val_loss: 0.0000e+00
# Epoch 7/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6065 - loss: 0.0000e+00 - val_accuracy: 0.5858 - val_loss: 0.0000e+00
# Epoch 8/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6065 - loss: 0.0000e+00 - val_accuracy: 0.5858 - val_loss: 0.0000e+00
# Epoch 9/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6065 - loss: 0.0000e+00 - val_accuracy: 0.5858 - val_loss: 0.0000e+00
# Epoch 10/10
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.6065 - loss: 0.0000e+00 - val_accuracy: 0.5858 - val_loss: 0.0000e+00

# %%
#use model.predict to predict the survival rate on the test dataset and print the predictions
model.predict(X_test)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# array([[3.58968123e-25],
#        [1.00235181e-24],
#        [5.11004650e-26],
#        [4.04172468e-22],
#        [6.88158823e-20],
#        [2.90055547e-17],
#        [1.04260572e-19],
#        [5.42484251e-33],
#        [8.05519286e-19],
#        [9.27173402e-23],
#        [8.49283768e-26],
#        [1.34819757e-27],
#        [3.40043848e-36],
#        [6.41849999e-22],
#        [4.43188713e-25],
#        [2.02993909e-19],
#        [4.03704776e-26],
#        [1.04065073e-19],
#        [1.01187389e-20],
#        [6.73076319e-23],
#        [2.79143608e-26],
#        [8.81451214e-22],
#        [6.34516522e-25],
#        [4.95454692e-26],
#        [1.00712647e-26],
#        [3.91150186e-39],
#        [2.22815169e-11],
#        [9.44521996e-25],
# Out:
# 709    1
# 439    0
# 840    0
# 720    1
# 39     1
# Name: Survived, dtype: int64

# %%
# What do you infer from these predictions

# %% [markdown]
# Now you have created an ANN that can predict if a person could have survived on the titanic or not. How cool is that!

# %% [markdown]
# Like ANNs, various other Neural Networks, each with their own Uniqueness Exist. Some are CNN (Convoluted NN) and RNN (Recurrent NN). Let's know more about them and use them for a particular problem.

# %% [markdown]
# ## CNN

# %% [markdown]
# CNN are a special type of Neural Network that roughly imitate Human Vision. It uses a special technique called Convolution. Now in mathematics convolution is a mathematical operation on two functions that produces a third function that expresses how the shape of one is modified by the other. Convolutional neural networks are composed of multiple layers of artificial neurons. You can read more about them on https://www.analyticsvidhya.com/blog/2021/05/convolutional-neural-networks-cnn/.
#
# We will be learning these in detail in the later tasks.
#
# **But when should you use a Convolutional Neural Network instead of an Artificial Neural Network?**
#
# 1. CNNs work best when the data can be represented in a spatial manner, say an image in MxN pixels. If you data is just as useful after shuffling any of your columns with each other then you cannot use CNN.
#
# 2. For example take into consideration the titanic dataset which you worked on. It had two columns (or features), namely age and gender , and if I were to swap the two columns (before feeding it to my network) it would make no difference whatsoever to my dataset. ANNs are preferred for such datasets
#
# 3. On the contrary, if we were to swap the columns (which are essentially pixel arrays) in an image, we are surely going to mess up an actual image. Hence, using ANNs is a big no-no and you must use CNNs.

# %% [markdown]
# Let's use CNN on the CIFAR Dataset

# %%
import tensorflow as tf

from tensorflow.keras import datasets, layers, models
import matplotlib.pyplot as plt

# %% [markdown]
# ### Download and prepare the CIFAR10 dataset
#
#
# The CIFAR10 dataset contains 60,000 color images in 10 classes, with 6,000 images in each class. The dataset is divided into 50,000 training images and 10,000 testing images. The classes are mutually exclusive and there is no overlap between them.

# %%
(train_images, train_labels), (test_images, test_labels) = datasets.cifar10.load_data()

# Normalize pixel values to be between 0 and 1
train_images, test_images = train_images / 255.0, test_images / 255.0

# %% [markdown]
# ### Verify the data
#
# To verify that the dataset looks correct, let's plot the first 25 images from the training set and display the class name below each image:

# %%
class_names = ['airplane', 'automobile', 'bird', 'cat', 'deer',
               'dog', 'frog', 'horse', 'ship', 'truck']

plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(train_images[i])
    # The CIFAR labels happen to be arrays,
    # which is why you need the extra index
    plt.xlabel(class_names[train_labels[i][0]])
plt.show()

# %% [markdown]
# ### Create the convolutional base

# %% [markdown]
# The 6 lines of code below define the convolutional base using a common pattern: a stack of [Conv2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D) and [MaxPooling2D](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPool2D) layers.
#
# As input, a CNN takes tensors of shape (image_height, image_width, color_channels), ignoring the batch size. If you are new to these dimensions, color_channels refers to (R,G,B). In this example, you will configure your CNN to process inputs of shape (32, 32, 3), which is the format of CIFAR images. You can do this by passing the argument `input_shape` to your first layer.

# %%
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(layers.MaxPooling2D((2, 2)))
# Now add another Conv2D followed by a MaxPool and another Conv2D... set the parameters according to what feels right to you and give a justification for the same
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# Let's display the architecture of your model so far:

# %%
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)                    │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 13, 13, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 4, 4, 64)            │          36,928 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 56,320 (220.00 KB)
#  Trainable params: 56,320 (220.00 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Above, you can see that the output of every Conv2D and MaxPooling2D layer is a 3D tensor of shape (height, width, channels). The width and height dimensions tend to shrink as you go deeper in the network. The number of output channels for each Conv2D layer is controlled by the first argument (e.g., 32 or 64). Typically,  as the width and height shrink, you can afford (computationally) to add more output channels in each Conv2D layer.

# %% [markdown]
# ### Add Dense layers on top
#
# To complete the model, you will feed the last output tensor from the convolutional base (of shape (4, 4, 64)) into one or more Dense layers to perform classification. Dense layers take vectors as input (which are 1D), while the current output is a 3D tensor. First, you will flatten (or unroll) the 3D output to 1D,  then add one or more Dense layers on top. CIFAR has 10 output classes, so you use a final Dense layer with 10 outputs.

# %%
model.add(layers.Flatten())
model.add(layers.Dense(64, activation='relu'))
model.add(layers.Dense(10,activation='softmax'))

# %% [markdown]
# Here's the complete architecture of your model:

# %%
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)                    │ (None, 30, 30, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 15, 15, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 13, 13, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 6, 6, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 4, 4, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 1024)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_19 (Dense)                     │ (None, 64)                  │          65,600 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_20 (Dense)                     │ (None, 10)                  │             650 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 10)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_21 (Dense)                     │ (None, 64)                  │             704 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_22 (Dense)                     │ (None, 10)                  │             650 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 123,924 (484.08 KB)
#  Trainable params: 123,924 (484.08 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# The network summary shows that (4, 4, 64) outputs were flattened into vectors of shape (1024) before going through two Dense layers.

# %% [markdown]
# ### Compile and train the model (Might take around 10-15 minutes)

# %%
model.compile(optimizer='adam', # Set Optimizer as adam
              loss= 'sparse_categorical_crossentropy', # Use Sparse categorical crossentropy as loss
              metrics=['accuracy']) # Use accuracy as the metric

history = model.fit(train_images, train_labels, epochs=20,
                    validation_data=(test_images, test_labels))
# Out:
# Epoch 1/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.7974 - loss: 0.5812 - val_accuracy: 0.6945 - val_loss: 0.9876
# Epoch 2/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.8096 - loss: 0.5458 - val_accuracy: 0.6902 - val_loss: 1.0251
# Epoch 3/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8139 - loss: 0.5309 - val_accuracy: 0.6874 - val_loss: 1.0799
# Epoch 4/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8215 - loss: 0.5043 - val_accuracy: 0.6841 - val_loss: 1.1481
# Epoch 5/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8304 - loss: 0.4839 - val_accuracy: 0.6905 - val_loss: 1.1902
# Epoch 6/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.8436 - loss: 0.4540 - val_accuracy: 0.6854 - val_loss: 1.1947
# Epoch 7/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8441 - loss: 0.4431 - val_accuracy: 0.6855 - val_loss: 1.2183
# Epoch 8/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8507 - loss: 0.4213 - val_accuracy: 0.6894 - val_loss: 1.2384
# Epoch 9/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8575 - loss: 0.3968 - val_accuracy: 0.6807 - val_loss: 1.3004
# Epoch 10/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8631 - loss: 0.3871 - val_accuracy: 0.6804 - val_loss: 1.3129
# Epoch 11/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8670 - loss: 0.3719 - val_accuracy: 0.6869 - val_loss: 1.3124
# Epoch 12/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 10s 3ms/step - accuracy: 0.8738 - loss: 0.3584 - val_accuracy: 0.6700 - val_loss: 1.3959
# Epoch 13/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.8791 - loss: 0.3421 - val_accuracy: 0.6735 - val_loss: 1.4199
# Epoch 14/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8813 - loss: 0.3256 - val_accuracy: 0.6757 - val_loss: 1.4078
# Epoch 15/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.8878 - loss: 0.3175 - val_accuracy: 0.6721 - val_loss: 1.5094
# Epoch 16/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8893 - loss: 0.3083 - val_accuracy: 0.6739 - val_loss: 1.5292
# Epoch 17/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8970 - loss: 0.2902 - val_accuracy: 0.6680 - val_loss: 1.6250
# Epoch 18/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8955 - loss: 0.2877 - val_accuracy: 0.6700 - val_loss: 1.6424
# Epoch 19/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9015 - loss: 0.2818 - val_accuracy: 0.6716 - val_loss: 1.6997
# Epoch 20/20
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9076 - loss: 0.2567 - val_accuracy: 0.6721 - val_loss: 1.6498

# %% [markdown]
# ### Evaluate the model

# %%
plt.plot(history.history['accuracy'], label='accuracy')
plt.plot(history.history['val_accuracy'], label = 'val_accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.ylim([0.5, 1])
plt.legend(loc='lower right')

test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
# Out:
# 313/313 - 1s - 2ms/step - accuracy: 0.6721 - loss: 1.6498

# %%
print(test_acc)
# Out:
# 0.6721000075340271

# %% [markdown]
# Your simple CNN has achieved a test accuracy of over 70%. Not bad for a few lines of code!

# %% [markdown]
# ## RNN

# %% [markdown]
# In a recurrent neural network we store the output activations from one or more of the layers of the network. Often these are hidden later activations. Then, the next time we feed an input example to the network, we include the previously-stored outputs as additional inputs. You can think of the additional inputs as being concatenated to the end of the “normal” inputs to the previous layer.

# %% [markdown]
# A simple explanation of RNN : https://www.youtube.com/watch?v=UNmqTiOnRfg&t=3s

# %% [markdown]
# ## RESEARCH

# %% [markdown]
#  **Find out about LSTM, and further usage of various types of RNNs.
# Also Find out about Time Series Forecasting and what it is**

# %% [markdown]
# ###Understanding LSTM, RNNs, and Time Series Forecasting
#
# Recurrent Neural Networks (RNNs) are a type of neural network designed for handling sequential data, where the order of inputs matters. Unlike traditional neural networks that treat inputs independently, RNNs have a "memory" that allows them to consider previous inputs when processing the current one. This makes RNNs particularly useful for tasks like language translation, speech recognition, and even predicting stock prices.
#
# However, one of the challenges with RNNs is something called the vanishing gradient problem. When training on long sequences, RNNs tend to "forget" the earlier parts of the sequence, making it difficult to capture long-term dependencies. This is where LSTMs, or Long Short-Term Memory networks, come into play.
#
# LSTMs are a specialized version of RNNs designed to retain information over long sequences. They achieve this through a unique architecture involving gates—input, forget, and output gates. These gates decide what information to keep, what to forget, and what to output at each step. For instance, in a text prediction task, LSTMs can remember the context from earlier parts of a sentence, which helps in making accurate predictions.
#
# Apart from LSTMs, there are other types of RNNs like GRUs (Gated Recurrent Units), which work similarly to LSTMs but are computationally simpler and faster. Variants of RNNs have broad applications, from chatbots and music generation to healthcare diagnostics and financial modeling. Each type has its strengths and is chosen based on the complexity and requirements of the task.
#
# A key application area for these models is Time Series Forecasting, which involves predicting future values based on past trends in sequential data. For example, businesses use time series forecasting to predict sales, plan inventory, or anticipate market trends. Meteorologists use it to forecast weather patterns, and financial analysts rely on it to predict stock prices or economic indicators.
#
# Time series data is unique because it has an inherent temporal structure—what happens at one time step is often influenced by what happened before. Simple statistical methods like ARIMA (AutoRegressive Integrated Moving Average) have been used for time series forecasting for decades. However, neural networks, especially RNNs and LSTMs, have proven to be more powerful in capturing complex patterns and long-term dependencies in data.
#
# For example, when predicting electricity consumption for a city, an LSTM can analyze past usage patterns while also considering factors like time of day or season. This makes predictions more accurate compared to traditional methods.
#
# What fascinates me about this topic is how RNNs and LSTMs mimic the way humans process information sequentially. It feels like giving machines the ability to "remember" and "anticipate" based on past experiences. While I’m still learning about the details, I can already see how these models are shaping industries and solving real-world problems. Diving deeper into time series forecasting and the advanced use cases of RNNs seems like a gateway to understanding the future of AI in decision-making and predictions.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
